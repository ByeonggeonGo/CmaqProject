# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import numpy as np
from netCDF4 import Dataset
import seaborn as sns
import matplotlib.pyplot as plt
path = os.getcwd()

# %% [markdown]
# * 데이터셋

# %%
# In[] SMOKE-CMAQ
# CMAQ 연평균 PM농도
pm2_5 = np.array([])

for i in range(1,120):
    a = 'ACONC.' + str(i)
    nc = Dataset(a, 'r')
    pm2_5 = np.append(pm2_5, np.array([[[nc.variables['PM2_5']]]]))
    
pm2_5 = np.reshape(pm2_5, [119,82,67])
pm2_5 = pm2_5[:,8:-10,2:-1]
pm2_5 = np.reshape(pm2_5, [119,64,64]) # convolution 연산을 위해

pm = pm2_5


y1 = np.array([])
y2 = np.array([])
y3 = np.array([])
y4 = np.array([])
y5 = np.array([])
y6 = np.array([])

for i in range(1,120):
    a = 'EMIS_AVG.' + str(i)
    nc = Dataset(a, 'r')
    y1 = np.append(y1, np.array([[[nc.variables['SO2']]]]))
    y2 = np.append(y2, np.array([[[nc.variables['PM2_5']]]]))
    y3 = np.append(y3, np.array([[[nc.variables['NOx']]]]))
    y4 = np.append(y4, np.array([[[nc.variables['VOCs']]]]))
    y5 = np.append(y5, np.array([[[nc.variables['NH3']]]]))
    y6 = np.append(y6, np.array([[[nc.variables['CO']]]]))
    
y1 = np.reshape(y1, [119,82,67])
y1 = y1[:,8:-10,2:-1]
y1 = np.reshape(y1, [119,64,64])
y1_max = np.max(y1)
y1_min = np.min(y1)

y2 = np.reshape(y2, [119,82,67])
y2 = y2[:,8:-10,2:-1]
y2 = np.reshape(y2, [119,64,64])
y2_max = np.max(y2)
y2_min = np.min(y2)

y3 = np.reshape(y3, [119,82,67])
y3 = y3[:,8:-10,2:-1]
y3 = np.reshape(y3, [119,64,64])
y3_max = np.max(y3)
y3_min = np.min(y3)

y4 = np.reshape(y4, [119,82,67])
y4 = y4[:,8:-10,2:-1]
y4 = np.reshape(y4, [119,64,64])
y4_max = np.max(y4)
y4_min = np.min(y4)

y5 = np.reshape(y5, [119,82,67])
y5 = y5[:,8:-10,2:-1]
y5 = np.reshape(y5, [119,64,64])
y5_max = np.max(y5)
y5_min = np.min(y5)
    
y6 = np.reshape(y6, [119,82,67])
y6 = y6[:,8:-10,2:-1]
y6 = np.reshape(y6, [119,64,64])


def pm_data():
    a = np.concatenate((y3,y1,y4,y5), axis=0) # PM2.5, SO2, NH3
    a = np.reshape(a,[4,119,64,64]) # data generation for CNN ??
    a = np.transpose(a, (1,2,3,0)) # CNN 학습을 위한 순서변경
    print(np.shape(a))
    
    y = pm
    
    y = np.reshape(y, [119,64,64,1]) # CNN output data
    x_train = a[0:70]
    y_train = y[0:70]
    x_test = a[70:]
    pm2_5 = y[70:]
    return x_train, y_train, x_test, pm2_5, a, y


pm_data1 = pm_data()
x_train, y_train, x_test, pm2_5, a, y = pm_data1[0], pm_data1[1], pm_data1[2], pm_data1[3], pm_data1[4], pm_data1[5]#, pm_data1[6], pm_data1[7]
# Out:
# (119, 64, 64, 4)

# %% [markdown]
# * 기본트리 학습

# %%
class tree():
    def __init__(
        self,
        max_depth: float,
        i_depth: float,
        minimum_sample_leaf: float,
        y_val: np.array,
        x_val: np.array,
        is_terminal: bool,

        kernel_size: list,
        kernel_n: int,

        input_shape: list,
    ):
        self.max_depth = max_depth
        self.minimum_sample_leaf = minimum_sample_leaf
        self.i_depth = i_depth
        self.is_terminal = is_terminal

        self.y_val = y_val
        self.x_val = x_val
        self.best_feature = None
        self.best_feature_value = None

        self.kernel_size = kernel_size#[3,3]
        self.kernel_n = kernel_n# 30
        self.input_shape = input_shape # [70,64,64,3]

        self.pred_val = None # 갖는 이미지의 평균값, 피팅이 완료되면 y_val, x_val은 버리도록(메모리낭비)

        self.l_tree = None
        self.r_tree = None

        ax1 = np.random.randint(input_shape[1] - kernel_size[0], size=kernel_n).reshape(-1,1)
        ax2 = np.random.randint(input_shape[2] - kernel_size[1], size=kernel_n).reshape(-1,1)
        ax3 = np.random.randint(input_shape[3], size=kernel_n).reshape(-1,1)

        self.kernel_cords = np.concatenate([ax1,ax2,ax3],axis = 1)


    def obj_fun(self, l_values, r_values):

        # np.mean(y, axis = 0)
        l_mean = np.mean(l_values, axis = 0)  # 0차원이 샘플수 일때
        r_mean = np.mean(r_values, axis = 0)

        l_len = len(l_values)
        r_len = len(r_values)
        # np.mean(((l_values - np.mean(l_values, axis = 0))**2)**0.5, axis = 0)
        l_mse = np.mean(np.mean(((l_values - np.mean(l_values, axis = 0))**2)**0.5, axis = 0))
        r_mse = np.mean(np.mean(((r_values - np.mean(r_values, axis = 0))**2)**0.5, axis = 0))

        mse_weighted =  (l_mse * l_len + r_mse * r_len)/(l_len + r_len)

        return mse_weighted
        


    def fit(self, ):
        best_score = None
        for cords in self.kernel_cords:  #컬럼_피처 루프
            
            feat_data = self.x_val[:,cords[0]:cords[0]+self.kernel_size[0],cords[1]:cords[1]+self.kernel_size[1],cords[2]]


            if len(set(feat_data.mean(axis = (1,2)))) == 1:
                continue
            elif len(set(feat_data.mean(axis = (1,2)))) >= 100:
                selected_feat_vals = list(np.random.choice(list(set(feat_data.mean(axis = (1,2)))),100, replace = False))
            else:
                selected_feat_vals = list(set(feat_data.mean(axis = (1,2))))

            for j in selected_feat_vals: #한 컬럼내에서 분류기준나누기 위한 루프

                left_ind = feat_data.mean(axis = (1,2)) < j

                y_left = self.y_val[left_ind]
                y_right = self.y_val[~left_ind]

                if self.best_feature is None:
                    self.best_feature = cords
                    self.best_feature_value = j
                    best_score = self.obj_fun(y_left, y_right)
                    
                else:
                    new_score = self.obj_fun(y_left, y_right)
                    if new_score < best_score:
                        self.best_feature = cords
                        self.best_feature_value = j
                        best_score = new_score
                        


        if self.max_depth >= self.i_depth:
            # 찾은 최적값으로 좌우 할당
            x_val_meaned_bykernel = self.x_val[:,self.best_feature[0]:self.best_feature[0]+self.kernel_size[0],self.best_feature[1]:self.best_feature[1]+self.kernel_size[1],self.best_feature[2]].mean(axis = (1,2))
    
            left_ind = x_val_meaned_bykernel < self.best_feature_value
            
            y_left = self.y_val[left_ind]
            y_right = self.y_val[~left_ind]

            x_left = self.x_val[left_ind]
            x_right = self.x_val[~left_ind]

            if len(y_left) > self.minimum_sample_leaf:
                self.l_tree = tree(max_depth = self.max_depth,i_depth = self.i_depth + 1, minimum_sample_leaf = self.minimum_sample_leaf, x_val = x_left, y_val = y_left, is_terminal=False, kernel_size=self.kernel_size, kernel_n=self.kernel_n, input_shape=self.input_shape)
                self.l_tree.fit()
            else:
                #마지막 리프라서 피팅할필요 없이 y_val 평균으로 예측만 하면 됨
                self.l_tree = tree(max_depth = self.max_depth,i_depth = self.i_depth + 1, minimum_sample_leaf = self.minimum_sample_leaf, x_val = x_left, y_val = y_left, is_terminal=True, kernel_size=self.kernel_size, kernel_n=self.kernel_n, input_shape=self.input_shape)

            if len(y_right) > self.minimum_sample_leaf:
                self.r_tree = tree(max_depth = self.max_depth,i_depth = self.i_depth + 1, minimum_sample_leaf = self.minimum_sample_leaf, x_val = x_right, y_val = y_right, is_terminal=False, kernel_size=self.kernel_size, kernel_n=self.kernel_n, input_shape=self.input_shape)
                self.r_tree.fit()
            else:
                #마지막 리프라서 피팅할필요 없이 y_val 평균으로 예측만 하면 됨
                self.r_tree = tree(max_depth = self.max_depth,i_depth = self.i_depth + 1, minimum_sample_leaf = self.minimum_sample_leaf, x_val = x_right, y_val = y_right, is_terminal=True, kernel_size=self.kernel_size, kernel_n=self.kernel_n, input_shape=self.input_shape)
        
        else:
            self.is_terminal = True


    def i_pred(self,x_data):
        if self.is_terminal:
            pred = self.y_val.mean(axis = 0)
            return pred
        
        i_x_val_meaned_bykernel = x_data[self.best_feature[0]:self.best_feature[0]+self.kernel_size[0],self.best_feature[1]:self.best_feature[1]+self.kernel_size[1],self.best_feature[2]].mean(axis = (0,1))
    

        if i_x_val_meaned_bykernel < self.best_feature_value:
            if self.l_tree.is_terminal:
                pred = self.l_tree.y_val.mean(axis = 0)   # 트리가 자료를 지니고있을 필요는 없음 (평균값만 저장하면 됨)
            else:
                pred = self.l_tree.i_pred(x_data)
        else:
            if self.r_tree.is_terminal:
                pred = self.r_tree.y_val.mean(axis = 0)
            else:
                pred = self.r_tree.i_pred(x_data)

        return pred.reshape(-1,64,64,1)

    def prediction(self, x_arr):

        if len(x_arr.shape) != 4:
            raise Exception('shape error')
        else:
        
            results = []
            for i in range(len(x_arr)):
                i_val = x_arr[i,:]
                
                result = self.i_pred(i_val)
                results.append(result)

            return results
    
    def get_tree_structure(self):
        def get_info_dic(i_tree):
            result = {
            'best_feature': i_tree.best_feature,
            'best_feature_value': i_tree.best_feature_value,
            'terminal': i_tree.is_terminal,
            'depth': i_tree.i_depth,
            }
            
            if i_tree.l_tree is not None:
                result['l_tree'] = get_info_dic(i_tree.l_tree)
            
            if i_tree.r_tree is not None:
                result['r_tree'] = get_info_dic(i_tree.r_tree)

            return result
        
        info = get_info_dic(self)
        return info

# %%
kernel_size = [3,3]
kernel_n = 30
input_shape = list(x_train.shape)

model = tree(max_depth = 5,i_depth = 0, minimum_sample_leaf = 2, x_val = x_train, y_val = y_train, is_terminal=False, kernel_size=kernel_size, kernel_n=kernel_n, input_shape=input_shape)
model.fit()

# %%
model.get_tree_structure()
# Out:
# {'best_feature': array([55, 24,  3]),
#  'best_feature_value': 0.43785423868232304,
#  'terminal': False,
#  'depth': 0,
#  'l_tree': {'best_feature': array([36, 39,  3]),
#   'best_feature_value': 0.22943166229459974,
#   'terminal': False,
#   'depth': 1,
#   'l_tree': {'best_feature': array([12, 33,  3]),
#    'best_feature_value': 0.004092654808320933,
#    'terminal': False,
#    'depth': 2,
#    'l_tree': {'best_feature': None,
#     'best_feature_value': None,
#     'terminal': True,
#     'depth': 3},
#    'r_tree': {'best_feature': array([32, 28,  3]),
#     'best_feature_value': 0.4869480033715566,
#     'terminal': False,
#     'depth': 3,
#     'l_tree': {'best_feature': None,
#      'best_feature_value': None,
#      'terminal': True,
#      'depth': 4},
#     'r_tree': {'best_feature': array([48, 44,  3]),
#      'best_feature_value': 0.04015609994530678,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': array([11, 12,  1]),
#       'best_feature_value': 1.7122373618702923e-06,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': array([17, 28,  3]),
#        'best_feature_value': 0.32825599362452823,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': array([39, 36,  3]),
#        'best_feature_value': 0.15862090057796902,
#        'terminal': True,
#        'depth': 6}},
#      'r_tree': {'best_feature': array([31, 40,  1]),
#       'best_feature_value': 0.041680480974415936,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': array([30, 19,  1]),
#        'best_feature_value': 1.0484089418443748e-05,
#        'terminal': True,
#        'depth': 6}}}}},
#   'r_tree': {'best_feature': array([48, 41,  3]),
#    'best_feature_value': 0.03823281452059746,
#    'terminal': False,
#    'depth': 2,
#    'l_tree': {'best_feature': array([46, 35,  2]),
#     'best_feature_value': 0.06485327374604014,
#     'terminal': False,
#     'depth': 3,
#     'l_tree': {'best_feature': array([43, 34,  3]),
#      'best_feature_value': 0.5891391899850633,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': array([53, 18,  2]),
#       'best_feature_value': 0.004368084579052973,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': array([30, 40,  0]),
#        'best_feature_value': 1.1031393988264933,
#        'terminal': True,
#        'depth': 6}},
#      'r_tree': {'best_feature': None,
#       'best_feature_value': None,
#       'terminal': True,
#       'depth': 5}},
#     'r_tree': {'best_feature': array([31, 35,  2]),
#      'best_feature_value': 0.08425529218382305,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': array([60, 28,  3]),
#       'best_feature_value': 0.06451915450290674,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': array([34, 16,  2]),
#        'best_feature_value': 0.0011555709074476301,
#        'terminal': True,
#        'depth': 6}},
#      'r_tree': {'best_feature': array([57, 43,  3]),
#       'best_feature_value': 0.01127426176228457,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6}}}},
#    'r_tree': {'best_feature': array([30, 31,  2]),
#     'best_feature_value': 0.07884186257918675,
#     'terminal': False,
#     'depth': 3,
#     'l_tree': {'best_feature': array([11, 32,  2]),
#      'best_feature_value': 0.0014967505606667448,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': array([35, 21,  2]),
#       'best_feature_value': 0.05248404675323096,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': array([13, 34,  3]),
#        'best_feature_value': 0.011540592282674171,
#        'terminal': True,
#        'depth': 6}},
#      'r_tree': {'best_feature': None,
#       'best_feature_value': None,
#       'terminal': True,
#       'depth': 5}},
#     'r_tree': {'best_feature': array([59, 36,  1]),
#      'best_feature_value': 0.0019287153483686678,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': array([16, 23,  1]),
#       'best_feature_value': 0.007592594225166572,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6}},
#      'r_tree': {'best_feature': None,
#       'best_feature_value': None,
#       'terminal': True,
#       'depth': 5}}}}},
#  'r_tree': {'best_feature': array([42, 28,  3]),
#   'best_feature_value': 1.2163436942630343,
#   'terminal': False,
#   'depth': 1,
#   'l_tree': {'best_feature': array([57, 42,  3]),
#    'best_feature_value': 0.043881352318243846,
#    'terminal': False,
#    'depth': 2,
#    'l_tree': {'best_feature': array([13,  8,  3]),
#     'best_feature_value': 0.00034602737287059426,
#     'terminal': False,
#     'depth': 3,
#     'l_tree': {'best_feature': array([10, 14,  1]),
#      'best_feature_value': 3.5262532446778277e-07,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': array([14, 35,  2]),
#       'best_feature_value': 0.02399398212865991,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': array([47, 37,  3]),
#        'best_feature_value': 0.14251918428474003,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6}},
#      'r_tree': {'best_feature': None,
#       'best_feature_value': None,
#       'terminal': True,
#       'depth': 5}},
#     'r_tree': {'best_feature': None,
#      'best_feature_value': None,
#      'terminal': True,
#      'depth': 4}},
#    'r_tree': {'best_feature': array([17, 34,  2]),
#     'best_feature_value': 0.45365672279149294,
#     'terminal': False,
#     'depth': 3,
#     'l_tree': {'best_feature': None,
#      'best_feature_value': None,
#      'terminal': True,
#      'depth': 4},
#     'r_tree': {'best_feature': array([34, 35,  3]),
#      'best_feature_value': 0.21036362482441795,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': None,
#       'best_feature_value': None,
#       'terminal': True,
#       'depth': 5},
#      'r_tree': {'best_feature': array([31, 50,  3]),
#       'best_feature_value': 0.33062641239828533,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': array([49, 23,  1]),
#        'best_feature_value': 0.31323775472214443,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': None,
#        'best_feature_value': None,
#        'terminal': True,
#        'depth': 6}}}}},
#   'r_tree': {'best_feature': array([11, 12,  3]),
#    'best_feature_value': 8.750871024353223e-07,
#    'terminal': False,
#    'depth': 2,
#    'l_tree': {'best_feature': None,
#     'best_feature_value': None,
#     'terminal': True,
#     'depth': 3},
#    'r_tree': {'best_feature': array([25, 44,  2]),
#     'best_feature_value': 0.1810625158250332,
#     'terminal': False,
#     'depth': 3,
#     'l_tree': {'best_feature': array([33, 40,  1]),
#      'best_feature_value': 0.18790053640906182,
#      'terminal': False,
#      'depth': 4,
#      'l_tree': {'best_feature': None,
#       'best_feature_value': None,
#       'terminal': True,
#       'depth': 5},
#      'r_tree': {'best_feature': array([16, 16,  3]),
#       'best_feature_value': 0.040765406188762024,
#       'terminal': False,
#       'depth': 5,
#       'l_tree': {'best_feature': array([48, 34,  2]),
#        'best_feature_value': 0.18588782474398613,
#        'terminal': True,
#        'depth': 6},
#       'r_tree': {'best_feature': array([46, 36,  1]),
#        'best_feature_value': 0.010686811525374651,
#        'terminal': True,
#        'depth': 6}}},
#     'r_tree': {'best_feature': None,
#      'best_feature_value': None,
#      'terminal': True,
#      'depth': 4}}}}}

# %%
pred = np.concatenate(model.prediction(x_test))
# Out:
# C:\Users\Go\AppData\Local\Temp\ipykernel_20888\2178311320.py:135: RuntimeWarning: Mean of empty slice.
#   pred = self.l_tree.y_val.mean(axis = 0)   # 트리가 자료를 지니고있을 필요는 없음 (평균값만 저장하면 됨)

# %%
plt.plot(pred.reshape(-1), pm2_5[::-1].reshape(-1),'bo', markersize=1)
plt.plot([0,90],[0,90])

# %%
i = 0
fig = plt.figure(figsize = (20,10))
        
ax1_1 = fig.add_subplot(1,2,1)
ax1_1.title.set_text('pred')
sns.heatmap(pred[i][:,:,0][::-1], cmap = 'jet',ax = ax1_1,vmin=0, vmax=80)

ax1_2 = fig.add_subplot(1,2,2)
ax1_2.title.set_text('true')
sns.heatmap(pm2_5[i][:,:,0][::-1], cmap = 'jet',ax = ax1_2,vmin=0, vmax=80)
# Out:
# <AxesSubplot: title={'center': 'true'}>

# %%
i = 1
fig = plt.figure(figsize = (20,10))
        
ax1_1 = fig.add_subplot(1,2,1)
ax1_1.title.set_text('pred')
sns.heatmap(pred[i][:,:,0][::-1], cmap = 'jet',ax = ax1_1,vmin=0, vmax=80)

ax1_2 = fig.add_subplot(1,2,2)
ax1_2.title.set_text('true')
sns.heatmap(pm2_5[i][:,:,0][::-1], cmap = 'jet',ax = ax1_2,vmin=0, vmax=80)
# Out:
# <AxesSubplot: title={'center': 'true'}>

# %%
for i in range(len(pred)):

    
    fig = plt.figure(figsize = (20,10))
        
    ax1_1 = fig.add_subplot(1,2,1)
    ax1_1.title.set_text('pred')
    sns.heatmap(pred[i][:,:,0][::-1], cmap = 'jet',ax = ax1_1,vmin=0, vmax=80)

    ax1_2 = fig.add_subplot(1,2,2)
    ax1_2.title.set_text('true')
    sns.heatmap(pm2_5[i][:,:,0][::-1], cmap = 'jet',ax = ax1_2,vmin=0, vmax=80)

    plt.savefig(os.path.join(path,"plots","base_tree",f"base_tree_pred_{i}.png"))
    plt.close()
